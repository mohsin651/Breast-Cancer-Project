# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("breast-cancer-wisconsin.csv")
df.head()
# Out:
#    Sample code number  Clump Thickness  Uniformity of Cell Size  \
# 0             1000025                5                        1
# 1             1002945                5                        4
# 2             1015425                3                        1
# 3             1016277                6                        8
# 4             1017023                4                        1
#
#    Uniformity of Cell Shape  Marginal Adhesion  Single Epithelial Cell Size  \
# 0                         1                  1                            2
# 1                         4                  5                            7
# 2                         1                  1                            2
# 3                         8                  1                            3
# 4                         1                  3                            2
#
#    Bare Nuclei  Bland Chromatin  Normal Nucleoli  Mitoses  Class
# 0            1                3                1        1      2
# 1           10                3                2        1      2
# 2            2                3                1        1      2
# 3            4                3                7        1      2
# 4            1                3                1        1      2

# %%
df['Class'].value_counts()
# Out:
# 2    444
# 4    239
# Name: Class, dtype: int64

# %%
df['Uniformity of Cell Shape'].value_counts()
# Out:
# 1     346
# 10     58
# 2      58
# 3      53
# 4      43
# 5      32
# 7      30
# 6      29
# 8      27
# 9       7
# Name: Uniformity of Cell Shape, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Sample code number           683 non-null    int64
#  1   Clump Thickness              683 non-null    int64
#  2   Uniformity of Cell Size      683 non-null    int64
#  3   Uniformity of Cell Shape     683 non-null    int64
#  4   Marginal Adhesion            683 non-null    int64
#  5   Single Epithelial Cell Size  683 non-null    int64
#  6   Bare Nuclei                  683 non-null    int64
#  7   Bland Chromatin              683 non-null    int64
#  8   Normal Nucleoli              683 non-null    int64
#  9   Mitoses                      683 non-null    int64
#  10  Class                        683 non-null    int64
# dtypes: int64(11)
# memory usage: 58.8 KB

# %%
df.describe()
# Out:
#        Sample code number  Clump Thickness  Uniformity of Cell Size  \
# count        6.830000e+02       683.000000               683.000000
# mean         1.076720e+06         4.442167                 3.150805
# std          6.206440e+05         2.820761                 3.065145
# min          6.337500e+04         1.000000                 1.000000
# 25%          8.776170e+05         2.000000                 1.000000
# 50%          1.171795e+06         4.000000                 1.000000
# 75%          1.238705e+06         6.000000                 5.000000
# max          1.345435e+07        10.000000                10.000000
#
#        Uniformity of Cell Shape  Marginal Adhesion  \
# count                683.000000         683.000000
# mean                   3.215227           2.830161
# std                    2.988581           2.864562
# min                    1.000000           1.000000
# 25%                    1.000000           1.000000
# 50%                    1.000000           1.000000
# 75%                    5.000000           4.000000
# max                   10.000000          10.000000
#
#        Single Epithelial Cell Size  Bare Nuclei  Bland Chromatin  \
# count                   683.000000   683.000000       683.000000
# mean                      3.234261     3.544656         3.445095
# std                       2.223085     3.643857         2.449697
# min                       1.000000     1.000000         1.000000
# 25%                       2.000000     1.000000         2.000000
# 50%                       2.000000     1.000000         3.000000
# 75%                       4.000000     6.000000         5.000000
# max                      10.000000    10.000000        10.000000
#
#        Normal Nucleoli     Mitoses       Class
# count       683.000000  683.000000  683.000000
# mean          2.869693    1.603221    2.699854
# std           3.052666    1.732674    0.954592
# min           1.000000    1.000000    2.000000
# 25%           1.000000    1.000000    2.000000
# 50%           1.000000    1.000000    2.000000
# 75%           4.000000    1.000000    4.000000
# max          10.000000   10.000000    4.000000

# %%
df1 = df.drop(['Sample code number'], axis=1)

# %%
df.shape
# Out:
# (683, 11)

# %%
df.isna().sum()
# Out:
# Sample code number             0
# Clump Thickness                0
# Uniformity of Cell Size        0
# Uniformity of Cell Shape       0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Bland Chromatin                0
# Normal Nucleoli                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (683, 11)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df1.corr(), cmap='Blues', annot=True, linewidths=2, linecolor='black',)
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(12,12), layout=(5,3));

# %%
sns.pairplot(df.drop(['Sample code number'], axis=1), hue='Class')

# %%
data= df.drop(['Uniformity of Cell Shape','Sample code number'], axis=1)
X= data.drop('Class', axis=1)
y= data['Class']

# %%
from sklearn.model_selection import train_test_split, cross_val_score
X_train, X_test, y_train,y_test= train_test_split(X,y, test_size=0.30)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (478, 8)
# (205, 8)
# (478,)
# (205,)

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\mohsi\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\mohsi\anaconda3\lib\site-packages (from imblearn) (0.9.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\mohsi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\mohsi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.20.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\mohsi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mohsi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\mohsi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.1)

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()

# %%
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# 2    320
# 4    158
# Name: Class, dtype: int64
# 2    124
# 4     81
# Name: Class, dtype: int64

# %%
X_train_smote, y_train_smote = smote.fit_resample(X_train.astype('float'),y_train)
X_test_smote, y_test_smote = smote.fit_resample(X_test.astype('float'),y_test)

# %%
print(y_train_smote.value_counts())
print(y_test_smote.value_counts())
# Out:
# 4    320
# 2    320
# Name: Class, dtype: int64
# 2    124
# 4    124
# Name: Class, dtype: int64

# %%
X_train
# Out:
#      Clump Thickness  Uniformity of Cell Size  Marginal Adhesion  \
# 171                5                       10                  3
# 129                2                        1                  1
# 90                 4                        1                  1
# 492                1                        1                  1
# 586                1                        1                  1
# ..               ...                      ...                ...
# 512                4                        1                  1
# 205                8                       10                  8
# 81                 3                        1                  1
# 518                3                        1                  1
# 508                7                        5                 10
#
#      Single Epithelial Cell Size  Bare Nuclei  Bland Chromatin  \
# 171                            8            1                5
# 129                            2            1                3
# 90                             2            1                3
# 492                            2            4                1
# 586                            1            1                2
# ..                           ...          ...              ...
# 512                            2            1                3
# 205                            4            8                7
# 81                             2            2                7
# 518                            2            1                2
# 508                            4           10                5
#
#      Normal Nucleoli  Mitoses
# 171               10        3
# 129                1        1
# 90                 1        1
# 492                1        1
# 586                1        1
# ..               ...      ...
# 512                1        1
# 205                7        1
# 81                 1        1
# 518                1        1
# 508                3        1
#
# [478 rows x 8 columns]

# %%
print(X_train['Marginal Adhesion'].value_counts())
print(X_train_smote['Marginal Adhesion'].value_counts())
# Out:
# 1     283
# 3      44
# 2      37
# 10     36
# 4      19
# 8      18
# 5      16
# 6      12
# 7      11
# 9       2
# Name: Marginal Adhesion, dtype: int64
# 1.000000     288
# 10.000000     60
# 3.000000      49
# 2.000000      40
# 8.000000      27
#             ...
# 1.957495       1
# 3.926108       1
# 4.377477       1
# 4.973660       1
# 2.154362       1
# Name: Marginal Adhesion, Length: 111, dtype: int64

# %%
print('X_train-', X_train_smote.shape)
print('X_test-',X_test_smote.shape)
print('y_train-', y_train_smote.shape)
print('y_test-', y_test_smote.shape)
# Out:
# X_train- (640, 8)
# X_test- (248, 8)
# y_train- (640,)
# y_test- (248,)

# %%
y_test.value_counts()
# Out:
# 2    124
# 4     81
# Name: Class, dtype: int64

# %%
# this list will contain scores of all the ensemble ML models and models which are base estimator of ensemble models
scores=[]

# %% [markdown]
# ### 1- Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=5000)

model1=lr.fit(X_train_smote,y_train_smote)
prediction1=model1.predict(X_test_smote)

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test_smote,prediction1)
cm
# Out:
# array([[129,   4],
#        [  6, 127]], dtype=int64)

# %%
sns.heatmap(cm, annot=True,cmap='Blues', fmt='d')
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import accuracy_score
scores.append(accuracy_score(y_test_smote,prediction1))
accuracy_score(y_test_smote,prediction1)
# Out:
# 0.9624060150375939

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test_smote, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.96      0.97      0.96       133
#            4       0.97      0.95      0.96       133
#
#     accuracy                           0.96       266
#    macro avg       0.96      0.96      0.96       266
# weighted avg       0.96      0.96      0.96       266

# %% [markdown]
# ## 2- Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier(criterion='entropy', max_depth=15, min_samples_leaf=1, min_samples_split=2)
model2=dtc.fit(X_train_smote,y_train_smote)
prediction2=model2.predict(X_test_smote)
cm2= confusion_matrix(y_test_smote,prediction2)

# %%
cm2
# Out:
# array([[127,   6],
#        [  6, 127]], dtype=int64)

# %%
sns.heatmap(cm2, annot=True,cmap='Blues', fmt='d')
# Out:
# <AxesSubplot:>

# %%
scores.append(accuracy_score(y_test_smote,prediction2))
accuracy_score(y_test_smote,prediction2)
# Out:
# 0.9548872180451128

# %%
print(classification_report(y_test_smote, prediction2))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.95      0.95      0.95       133
#            4       0.95      0.95      0.95       133
#
#     accuracy                           0.95       266
#    macro avg       0.95      0.95      0.95       266
# weighted avg       0.95      0.95      0.95       266

# %% [markdown]
# ## 3- Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(bootstrap=False,
 max_depth=6,
 max_features='auto',
 min_samples_leaf=1,
 min_samples_split=2,
 n_estimators=10)
model3 = rfc.fit(X_train_smote, y_train_smote)
prediction3 = model3.predict(X_test_smote)
cm3=confusion_matrix(y_test_smote, prediction3)
# Out:
# C:\Users\hassa\AppData\Roaming\Python\Python39\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
sns.heatmap(cm3, annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
scores.append(accuracy_score(y_test_smote,prediction3))
accuracy_score(y_test_smote,prediction3)
# Out:
# 0.9774436090225563

# %%
print(classification_report(y_test_smote, prediction3))
# Out:
#               precision    recall  f1-score   support
#
#            2       1.00      0.95      0.98       133
#            4       0.96      1.00      0.98       133
#
#     accuracy                           0.98       266
#    macro avg       0.98      0.98      0.98       266
# weighted avg       0.98      0.98      0.98       266

# %% [markdown]
# ### SupportVectorClassifier

# %%
from sklearn.svm import SVC

svm=SVC(kernel='linear', probability=True)
model4=svm.fit(X_train_smote,y_train_smote)
prediction4=model4.predict(X_test_smote)
cm4= confusion_matrix(y_test_smote,prediction4)

# %%
cm4
# Out:
# array([[127,   6],
#        [  2, 131]], dtype=int64)

# %%
sns.heatmap(cm4, annot=True, cmap='Blues', fmt='d')
# Out:
# <AxesSubplot:>

# %%
scores.append(accuracy_score(y_test_smote,prediction4))
accuracy_score(y_test_smote, prediction4)
# Out:
# 0.9699248120300752

# %%
print(classification_report(y_test_smote, prediction4))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.98      0.95      0.97       133
#            4       0.96      0.98      0.97       133
#
#     accuracy                           0.97       266
#    macro avg       0.97      0.97      0.97       266
# weighted avg       0.97      0.97      0.97       266

# %% [markdown]
# ### 5- Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

NB = GaussianNB(var_smoothing= 2e-9)
model5 = NB.fit(X_train_smote, y_train_smote)
prediction5 = model5.predict(X_test_smote)
cm5=confusion_matrix(y_test_smote, prediction5)

# %%
cm5
# Out:
# array([[125,   8],
#        [  6, 127]], dtype=int64)

# %%
sns.heatmap(cm5, annot=True, cmap='Blues', fmt='d')
# Out:
# <AxesSubplot:>

# %%
scores.append(accuracy_score(y_test_smote,prediction5))
accuracy_score(y_test_smote, prediction5)
# Out:
# 0.9473684210526315

# %%
print(classification_report(y_test_smote, prediction5))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.95      0.94      0.95       133
#            4       0.94      0.95      0.95       133
#
#     accuracy                           0.95       266
#    macro avg       0.95      0.95      0.95       266
# weighted avg       0.95      0.95      0.95       266

# %% [markdown]
# ### 6- KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

KNN = KNeighborsClassifier(n_neighbors = 5, weights = 'uniform',algorithm = 'brute',metric = 'minkowski')
model6 = KNN.fit(X_train_smote, y_train_smote)
prediction6 = model6.predict(X_test_smote)
cm6=confusion_matrix(y_test_smote, prediction5)
cm6
# Out:
# array([[125,   8],
#        [  6, 127]], dtype=int64)

# %%
sns.heatmap(cm6, annot=True, cmap='Blues', fmt='d')
# Out:
# <AxesSubplot:>

# %%
scores.append(accuracy_score(y_test_smote,prediction6))
accuracy_score(y_test_smote, prediction6)
# Out:
# 0.9624060150375939

# %%
print(classification_report(y_test_smote, prediction6))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.97      0.95      0.96       133
#            4       0.96      0.97      0.96       133
#
#     accuracy                           0.96       266
#    macro avg       0.96      0.96      0.96       266
# weighted avg       0.96      0.96      0.96       266

# %% [markdown]
# ### Random Forest Model with Hyperparameter tuning using GridSearchCV

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 80, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [2,4, 6, 8]
# Minimum number of samples required to split a node
min_samples_split = [2, 50]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
# Create the paramaters grid
param_grid_1 = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}
print(param_grid_1)
# Out:
# {'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72, 80], 'max_features': ['auto', 'sqrt'], 'max_depth': [2, 4, 6, 8], 'min_samples_split': [2, 50], 'min_samples_leaf': [1, 2], 'bootstrap': [True, False]}

# %%
from sklearn.model_selection import GridSearchCV
E_model_1 = GridSearchCV(estimator = RandomForestClassifier(), param_grid = param_grid_1, cv = 3, verbose=5, n_jobs = -1)
E_model_1
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False], 'max_depth': [2, 4, 6, 8],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 50],
#                          'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72,
#                                           80]},
#              verbose=5)

# %%
E_model_1.fit(X_train_smote, y_train_smote)
# Out:
# Fitting 3 folds for each of 640 candidates, totalling 1920 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False], 'max_depth': [2, 4, 6, 8],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 50],
#                          'n_estimators': [10, 17, 25, 33, 41, 48, 56, 64, 72,
#                                           80]},
#              verbose=5)

# %%
# print(accuracy_score(y_test, E_predicted_1))
scores.append(E_model_1.best_score_)
E_model_1.best_score_
# Out:
# 0.9871330360460795

# %%
E_model_1.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 6,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 72}

# %%
E_prediction_1=E_model_1.predict(X_test_smote)
accuracy_score(y_test_smote, E_prediction_1)
# Out:
# 0.9774436090225563

# %%
print(classification_report(y_test_smote, E_prediction_1))
# Out:
#               precision    recall  f1-score   support
#
#            2       1.00      0.95      0.98       133
#            4       0.96      1.00      0.98       133
#
#     accuracy                           0.98       266
#    macro avg       0.98      0.98      0.98       266
# weighted avg       0.98      0.98      0.98       266

# %% [markdown]
# ### Decision Tree Classifier with Hyperparameter tuning using GridSearchCV

# %%
param_grid_2={
    'criterion': ['gini', 'entropy'],
    'max_depth': range(1, 10),
    'min_samples_split': range(1, 10),
    'min_samples_leaf': range(1, 5)
}

# %%
from sklearn.model_selection import GridSearchCV
E_model_2=GridSearchCV(estimator=DecisionTreeClassifier(), param_grid=param_grid_2, cv=10, n_jobs=-1)

# %%
E_model_2.fit(X_train_smote, y_train_smote)
# Out:
# C:\Users\hassa\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 720 fits failed out of a total of 6480.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 720 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\hassa\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\hassa\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py", line 969, in fit
#     super().fit(
#   File "C:\Users\hassa\AppData\Roaming\Python\Python39\site-packages\sklearn\tree\_classes.py", line 265, in fit
#     check_scalar(
#   File "C:\Users\hassa\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py", line 1480, in check_scalar
#     raise ValueError(
# ValueError: min_samples_split == 1, must be >= 2.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\hassa\AppData\Roaming\Python\Python39\site-packages\sklearn\model_selection\_search.py:953: UserWarning: One or more of the test scores are non-finite: [       nan 0.93896569 0.93896569 0.93896569 0.93896569 0.93896569
#  0.93896569 0.93896569 0.93896569        nan 0.93896569 0.93896569
#  0.93896569 0.93896569 0.93896569 0.93896569 0.93896569 0.93896569
#         nan 0.93896569 0.93896569 0.93896569 0.93896569 0.93896569
#  0.93896569 0.93896569 0.93896569        nan 0.93896569 0.93896569
#  0.93896569 0.93896569 0.93896569 0.93896569 0.93896569 0.93896569
#         nan 0.94856631 0.94856631 0.94856631 0.94856631 0.94856631
#  0.94856631 0.94856631 0.94856631        nan 0.94856631 0.94856631
#  0.94856631 0.94856631 0.94856631 0.94856631 0.94856631 0.94856631
#         nan 0.94856631 0.94856631 0.94856631 0.94856631 0.94856631
#  0.94856631 0.94856631 0.94856631        nan 0.94856631 0.94856631
#  0.94856631 0.94856631 0.94856631 0.94856631 0.94856631 0.94856631
#         nan 0.96618024 0.96618024 0.96618024 0.96618024 0.96618024
#  0.96618024 0.96618024 0.96618024        nan 0.96940604 0.96940604
#  0.96940604 0.96940604 0.96940604 0.96940604 0.96940604 0.96940604
#         nan 0.96940604 0.96940604 0.96940604 0.96940604 0.96940604
#  0.96940604 0.96940604 0.96940604        nan 0.96620584 0.96620584
#  0.96620584 0.96620584 0.96620584 0.96620584 0.96620584 0.96620584
#         nan 0.96459293 0.96620584 0.96459293 0.96459293 0.96141833
#  0.96459293 0.96303123 0.96141833        nan 0.96305684 0.96305684
#  0.96305684 0.96623144 0.96305684 0.96305684 0.96623144 0.96623144
#         nan 0.96781874 0.96781874 0.96620584 0.96781874 0.96781874
#  0.96781874 0.96781874 0.96781874        nan 0.96300563 0.96300563
#  0.96300563 0.96300563 0.96300563 0.96300563 0.96300563 0.96300563
#         nan 0.95499232 0.95499232 0.95655402 0.95816692 0.95499232
#  0.95337942 0.96300563 0.95980543        nan 0.95501792 0.95819252
#  0.95819252 0.95819252 0.95501792 0.95819252 0.96303123 0.96144393
#         nan 0.96461854 0.96139273 0.96139273 0.96139273 0.96461854
#  0.96139273 0.96461854 0.96459293        nan 0.95819252 0.95819252
#  0.95980543 0.95496672 0.95657962 0.95657962 0.95496672 0.95977983
#         nan 0.95337942 0.95332821 0.95017921 0.95179211 0.95340502
#  0.95337942 0.96139273 0.95819252        nan 0.96141833 0.95821813
#  0.95663082 0.95343062 0.95821813 0.96141833 0.96464414 0.96466974
#         nan 0.96945725 0.96139273 0.96461854 0.96784434 0.96139273
#  0.96139273 0.96139273 0.96298003        nan 0.95657962 0.95980543
#  0.95819252 0.95657962 0.95657962 0.95657962 0.95819252 0.95977983
#         nan 0.95335381 0.95017921 0.95494112 0.95494112 0.95337942
#  0.95176651 0.95821813 0.96136713        nan 0.95660522 0.95343062
#  0.95821813 0.95821813 0.95983103 0.95980543 0.96464414 0.96784434
#         nan 0.96461854 0.96461854 0.96784434 0.96623144 0.96300563
#  0.96461854 0.96139273 0.96620584        nan 0.95819252 0.95657962
#  0.95819252 0.95496672 0.95819252 0.95819252 0.95496672 0.96139273
#         nan 0.95337942 0.95660522 0.95015361 0.95499232 0.95337942
#  0.95499232 0.95983103 0.96459293        nan 0.95501792 0.95504352
#  0.95663082 0.95660522 0.95983103 0.95980543 0.96308244 0.96623144
#         nan 0.96784434 0.96784434 0.96784434 0.96623144 0.96461854
#  0.96139273 0.96461854 0.96620584        nan 0.95819252 0.95819252
#  0.95819252 0.95496672 0.95980543 0.95819252 0.95657962 0.95816692
#         nan 0.95330261 0.95176651 0.95337942 0.95496672 0.95657962
#  0.95494112 0.96139273 0.96298003        nan 0.95657962 0.95663082
#  0.95501792 0.95501792 0.96141833 0.96141833 0.96146953 0.96623144
#         nan 0.96945725 0.96945725 0.96945725 0.96461854 0.96461854
#  0.96461854 0.96139273 0.96459293        nan 0.95657962 0.95819252
#  0.95819252 0.95657962 0.95980543 0.95657962 0.95819252 0.96139273
#         nan 0.92616487 0.92616487 0.92616487 0.92616487 0.92616487
#  0.92616487 0.92616487 0.92616487        nan 0.92616487 0.92616487
#  0.92616487 0.92616487 0.92616487 0.92616487 0.92616487 0.92616487
#         nan 0.92616487 0.92616487 0.92616487 0.92616487 0.92616487
#  0.92616487 0.92616487 0.92616487        nan 0.92616487 0.92616487
#  0.92616487 0.92616487 0.92616487 0.92616487 0.92616487 0.92616487
#         nan 0.94861751 0.94861751 0.94861751 0.94861751 0.94861751
#  0.94861751 0.94861751 0.94861751        nan 0.94861751 0.94861751
#  0.94861751 0.94861751 0.94861751 0.94861751 0.94861751 0.94861751
#         nan 0.94861751 0.94861751 0.94861751 0.94861751 0.94861751
#  0.94861751 0.94861751 0.94861751        nan 0.94861751 0.94861751
#  0.94861751 0.94861751 0.94861751 0.94861751 0.94861751 0.94861751
#         nan 0.96136713 0.96136713 0.96136713 0.96136713 0.96136713
#  0.96136713 0.96136713 0.96136713        nan 0.96459293 0.96459293
#  0.96459293 0.96459293 0.96459293 0.96459293 0.96459293 0.96459293
#         nan 0.96459293 0.96459293 0.96459293 0.96459293 0.96459293
#  0.96459293 0.96459293 0.96459293        nan 0.96300563 0.96139273
#  0.96300563 0.96139273 0.95977983 0.96139273 0.96300563 0.96139273
#         nan 0.95983103 0.95983103 0.95660522 0.95660522 0.95660522
#  0.95983103 0.95660522 0.95819252        nan 0.95663082 0.95985663
#  0.95663082 0.95985663 0.95663082 0.95985663 0.95663082 0.95821813
#         nan 0.96141833 0.95980543 0.96141833 0.95980543 0.95980543
#  0.95980543 0.96303123 0.95980543        nan 0.95983103 0.96144393
#  0.95821813 0.96144393 0.95821813 0.95660522 0.95660522 0.96144393
#         nan 0.96139273 0.95819252 0.96298003 0.95980543 0.96298003
#  0.95819252 0.96464414 0.96623144        nan 0.95499232 0.95499232
#  0.95660522 0.95660522 0.95660522 0.95660522 0.96305684 0.96303123
#         nan 0.96618024 0.96618024 0.96779314 0.96300563 0.96618024
#  0.96461854 0.96461854 0.96300563        nan 0.96141833 0.95819252
#  0.95819252 0.96141833 0.95980543 0.95819252 0.95819252 0.96141833
#         nan 0.96141833 0.95980543 0.96141833 0.96144393 0.96144393
#  0.95983103 0.96466974 0.96786994        nan 0.95501792 0.95824373
#  0.96141833 0.96300563 0.96461854 0.95983103 0.96466974 0.96786994
#         nan 0.95983103 0.96945725 0.96300563 0.96303123 0.96300563
#  0.96144393 0.96144393 0.95983103        nan 0.95824373 0.95985663
#  0.95663082 0.95985663 0.95824373 0.95824373 0.95985663 0.95501792
#         nan 0.95983103 0.96141833 0.95663082 0.96461854 0.95824373
#  0.95985663 0.96469534 0.96466974        nan 0.95819252 0.95340502
#  0.95499232 0.95977983 0.95983103 0.96144393 0.96308244 0.96464414
#         nan 0.96628264 0.96305684 0.96466974 0.96141833 0.96303123
#  0.96144393 0.96144393 0.95983103        nan 0.95824373 0.95824373
#  0.95663082 0.96308244 0.96146953 0.95985663 0.95824373 0.95663082
#         nan 0.96139273 0.95980543 0.95980543 0.96461854 0.96144393
#  0.95983103 0.96466974 0.96628264        nan 0.95983103 0.96139273
#  0.95337942 0.95824373 0.96303123 0.95826933 0.96466974 0.96305684
#         nan 0.95983103 0.96623144 0.96466974 0.96300563 0.96784434
#  0.96144393 0.96144393 0.96144393        nan 0.95824373 0.96146953
#  0.95501792 0.95985663 0.95824373 0.95501792 0.95824373 0.95501792
#         nan 0.95983103 0.95499232 0.95821813 0.96141833 0.95983103
#  0.95985663 0.96308244 0.96466974        nan 0.95824373 0.95983103
#  0.95821813 0.95983103 0.96141833 0.95821813 0.96628264 0.96305684
#         nan 0.95983103 0.96461854 0.95983103 0.96461854 0.95983103
#  0.95983103 0.95983103 0.96144393        nan 0.95663082 0.95663082
#  0.95663082 0.95501792 0.95985663 0.95824373 0.96146953 0.95824373]
#   warnings.warn(
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(1, 10),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(1, 10)})

# %%
E_prediction_2=E_model_2.predict(X_test_smote)
accuracy_score(y_test_smote, E_prediction_2)
# Out:
# 0.9661654135338346

# %%
print(classification_report(y_test_smote, E_prediction_2))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.97      0.96      0.97       133
#            4       0.96      0.97      0.97       133
#
#     accuracy                           0.97       266
#    macro avg       0.97      0.97      0.97       266
# weighted avg       0.97      0.97      0.97       266

# %%
scores.append(E_model_2.best_score_)
E_model_2.best_score_
# Out:
# 0.9694572452636969

# %%
E_model_2.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 6,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2}

# %% [markdown]
# ### Adaboost Classifier with Hyperparameter tuning using GridSearchCV

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV
ADC=AdaBoostClassifier(n_estimators=150, learning_rate=1.5)
E_model_3=ADC.fit(X_train_smote, y_train_smote)
E_predicted_3=E_model_3.predict(X_test_smote)
accuracy_score(y_test_smote, E_predicted_3)
# Out:
# 0.9699248120300752

# %%
# Applying GridSearchCV
param_grid_3={
    'n_estimators': [10, 50, 75, 100, 150, 200],
    'learning_rate': [0.001, 0.01, 0.1, 1, 1.5, 2],
    'algorithm': ['SAMME', 'SAMME.R']
}

# %%
E_model_3=GridSearchCV(estimator=AdaBoostClassifier(), param_grid=param_grid_3, n_jobs=-1, cv=10, scoring='accuracy')

# %%
E_model_3.fit(X_train_smote, y_train_smote)
# Out:
# GridSearchCV(cv=10, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.001, 0.01, 0.1, 1, 1.5, 2],
#                          'n_estimators': [10, 50, 75, 100, 150, 200]},
#              scoring='accuracy')

# %%
E_prediction_3=E_model_3.predict(X_test_smote)
accuracy_score(y_test_smote, E_prediction_3)
# Out:
# 0.9586466165413534

# %%
scores.append(E_model_3.best_score_)
E_model_3.best_score_
# Out:
# 0.9742703533026115

# %%
print(classification_report(y_test_smote, E_prediction_3))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.98      0.94      0.96       133
#            4       0.94      0.98      0.96       133
#
#     accuracy                           0.96       266
#    macro avg       0.96      0.96      0.96       266
# weighted avg       0.96      0.96      0.96       266

# %%
E_model_3.best_params_
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.01, 'n_estimators': 200}

# %% [markdown]
# Gradient Boost Classifier with Hyperparameter tuning using GridSearchCV

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
GBC=GradientBoostingClassifier(n_estimators=16, learning_rate=1.59)
GradientBoostingClassifier()
E_model_4=GBC.fit(X_train_smote, y_train_smote)
E_predicted_4=E_model_4.predict(X_test_smote)
accuracy_score(y_test_smote, E_predicted_4)
# Out:
# 0.9699248120300752

# %%
#Applying GrirSearchCV
param_grid_4={
    'n_estimators': [10, 50, 75, 100, 150, 200],
    'learning_rate': [0.05, 0.1, 0.5, 1.0, 1.5]
}

# %%
E_model_4=GridSearchCV(estimator=GradientBoostingClassifier(), param_grid=param_grid_4, n_jobs=-1, cv=10, scoring='accuracy')
E_model_4.fit(X_train_smote, y_train_smote)
E_prediction_4 = E_model_4.predict(X_test_smote)

# %%
scores.append(E_model_4.best_score_)
E_model_4.best_score_
# Out:
# 0.9807219662058373

# %%
print(classification_report(y_test_smote, E_prediction_4))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.99      0.95      0.97       133
#            4       0.96      0.99      0.97       133
#
#     accuracy                           0.97       266
#    macro avg       0.97      0.97      0.97       266
# weighted avg       0.97      0.97      0.97       266

# %%
E_model_4.best_params_
# Out:
# {'learning_rate': 0.5, 'n_estimators': 75}

# %%
print(E_model_4)
# Out:
# GridSearchCV(cv=10, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.05, 0.1, 0.5, 1.0, 1.5],
#                          'n_estimators': [10, 50, 75, 100, 150, 200]},
#              scoring='accuracy')

# %% [markdown]
# ### XgBoost Classifier with Hyperparameter tuning using GridSearchCV

# %%
pip install xgboost==0.90
# Out:
# Requirement already satisfied: xgboost==0.90 in c:\users\hassa\appdata\local\programs\python\python39\lib\site-packages (0.90)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scipy in c:\users\hassa\appdata\local\programs\python\python39\lib\site-packages (from xgboost==0.90) (1.9.1)
# Requirement already satisfied: numpy in c:\users\hassa\appdata\local\programs\python\python39\lib\site-packages (from xgboost==0.90) (1.23.1)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y_train = le.fit_transform(y_train_smote)

# %%
from xgboost import XGBClassifier
XGB=XGBClassifier(n_estimators=100, learning_rate=0.01, max_depth=45)
E_model_5=XGB.fit(X_train_smote, y_train_smote)
E_predicted_5=E_model_5.predict(X_test_smote)
accuracy_score(y_test_smote, E_predicted_5)
# Out:
# 0.9624060150375939

# %%
# Applying GridSearchCV
param_grid_5={
    'n_estimators': [10, 50, 75, 100, 175, 150, 200],
    'learning_rate': [0.001, 0.01, 0.1, 0.4, 0.5, 0.6],
    'max_depth': [1, 2, 3, 4, 5, 6]
}

# %%
E_model_5=GridSearchCV(estimator=XGBClassifier(), param_grid=param_grid_5, verbose=1, n_jobs=-1, cv=5)
E_model_5.fit(X_train_smote, y_train_smote)
E_predicted_5=E_model_5.predict(X_test_smote)
# Out:
# Fitting 5 folds for each of 252 candidates, totalling 1260 fits

# %%
print(classification_report(y_test_smote, E_predicted_5))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.98      0.95      0.96       133
#            4       0.95      0.98      0.96       133
#
#     accuracy                           0.96       266
#    macro avg       0.96      0.96      0.96       266
# weighted avg       0.96      0.96      0.96       266

# %%
E_model_5.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}

# %%
scores.append(E_model_5.best_score_)
E_model_5.best_score_
# Out:
# 0.9807225806451614

# %% [markdown]
# ### LGBM Classifier with Hyperparameter tuning using GridSearchCV

# %%
pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\hassa\appdata\roaming\python\python39\site-packages (3.3.2)
# Requirement already satisfied: wheel in c:\users\hassa\appdata\local\programs\python\python39\lib\site-packages (from lightgbm) (0.38.4)
# Requirement already satisfied: scipy in c:\users\hassa\appdata\local\programs\python\python39\lib\site-packages (from lightgbm) (1.9.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\hassa\appdata\roaming\python\python39\site-packages (from lightgbm) (1.1.2)
# Requirement already satisfied: numpy in c:\users\hassa\appdata\local\programs\python\python39\lib\site-packages (from lightgbm) (1.23.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\hassa\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hassa\appdata\local\programs\python\python39\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from lightgbm import LGBMClassifier

# %%
LGB=LGBMClassifier(n_estimators=45, learning_rate=0.065, num_leaves=30, random_state=42, objective='binary')
E_model_6=LGB.fit(X_train_smote, y_train_smote)
E_predicted_6=E_model_6.predict(X_test_smote)
accuracy_score(y_test_smote, E_predicted_6)
# Out:
# 0.9661654135338346

# %%
# Applying GridSearchCV
param_grid_6={
    'n_estimators': [100, 200, 300, 400],
    'learning_rate': [0.001, 0.05, 0.1, 0.3],
    'num_leaves': [20, 50, 80, 100]
}

# %%
E_model_6=GridSearchCV(estimator=LGBMClassifier(), param_grid=param_grid_6, verbose=1, n_jobs=-1, cv=10)
E_model_6.fit(X_train_smote, y_train_smote)
E_predicted_6=E_model_6.predict(X_test_smote)
# Out:
# Fitting 10 folds for each of 64 candidates, totalling 640 fits

# %%
print(classification_report(E_predicted_6, y_test_smote))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.96      0.99      0.98       129
#            4       0.99      0.96      0.98       137
#
#     accuracy                           0.98       266
#    macro avg       0.98      0.98      0.98       266
# weighted avg       0.98      0.98      0.98       266

# %%
E_model_6.best_params_
# Out:
# {'learning_rate': 0.05, 'n_estimators': 200, 'num_leaves': 20}

# %%
scores.append(E_model_6.best_score_)
E_model_6.best_score_
# Out:
# 0.9806707629288276

# %% [markdown]
# Custom Classifier (PROPOSED METHOD)

# %%
data= df.drop(['Uniformity of Cell Shape','Sample code number'], axis=1)

X1 = data.iloc[:,:-1]
y1 = data.iloc[:,-1]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X_1 = LabelEncoder()
y1 = labelencoder_X_1.fit_transform(y)

# Splitting the dataset into the Training set and Test set (30 - 70)
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size = 0.3, random_state = 0)

#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train1 = sc.fit_transform(X_train1)
X_test1 = sc.transform(X_test1)


X_train_smote1, y_train_smote1 = smote.fit_resample(X_train1.astype('float'),y_train1)
X_test_smote1, y_test_smote1 = smote.fit_resample(X_test1.astype('float'),y_test1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16400/4226693362.py in <module>
#       5 # Splitting the dataset into the Training set and Test set (30 - 70)
#       6 from sklearn.model_selection import train_test_split
# ----> 7 X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size = 0.3, random_state = 0)
#       8
#       9 #Feature Scaling
#
# NameError: name 'X1' is not defined

# %%
print(y_train1.shape)
print(y_train_smote1.shape)
print(y_test1.shape)
print(y_test_smote1.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16400/2479479125.py in <module>
# ----> 1 print(y_train1.shape)
#       2 print(y_train_smote1.shape)
#       3 print(y_test1.shape)
#       4 print(y_test_smote1.shape)
#
# NameError: name 'y_train1' is not defined

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

classifier = Sequential()
classifier.add(Dense(units = 10, kernel_initializer = 'uniform', activation = 'relu',input_dim = 8)) #adding the first input and the first hidden layer
#adding dropout to prevent overfitting
classifier.add(Dropout(0.1))

#adding the second hidden layer
classifier.add(Dense(units = 5, kernel_initializer = 'uniform', activation = 'relu'))
#adding dropout to prevent overfitting
classifier.add(Dropout(0.1))

classifier.add(Dense(units = 1, kernel_initializer='uniform', activation = 'sigmoid'))

# %%
classifier.summary ()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                90
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense_1 (Dense)             (None, 5)                 55
#
#  dropout_1 (Dropout)         (None, 5)                 0
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy', metrics=('accuracy'))

# %%
classifier.fit(X_train_smote1, y_train_smote1, batch_size=5, epochs=70)
# Out:
# Epoch 1/70
# 126/126 [==============================] - 1s 2ms/step - loss: 0.6534 - accuracy: 0.8360
# Epoch 2/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.3036 - accuracy: 0.9697
# Epoch 3/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.9634
# Epoch 4/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0873 - accuracy: 0.9745
# Epoch 5/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0918 - accuracy: 0.9729
# Epoch 6/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0867 - accuracy: 0.9697
# Epoch 7/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0925 - accuracy: 0.9666
# Epoch 8/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0764 - accuracy: 0.9697
# Epoch 9/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0833 - accuracy: 0.9729
# Epoch 10/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0813 - accuracy: 0.9697
# Epoch 11/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0827 - accuracy: 0.9761
# Epoch 12/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0747 - accuracy: 0.9761
# Epoch 13/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0764 - accuracy: 0.9777
# Epoch 14/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0792 - accuracy: 0.9777
# Epoch 15/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0745 - accuracy: 0.9777
# Epoch 16/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0742 - accuracy: 0.9793
# Epoch 17/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9761
# Epoch 18/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0736 - accuracy: 0.9809
# Epoch 19/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0694 - accuracy: 0.9777
# Epoch 20/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0707 - accuracy: 0.9809
# Epoch 21/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0673 - accuracy: 0.9809
# Epoch 22/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0659 - accuracy: 0.9809
# Epoch 23/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0634 - accuracy: 0.9825
# Epoch 24/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0664 - accuracy: 0.9841
# Epoch 25/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0658 - accuracy: 0.9841
# Epoch 26/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0604 - accuracy: 0.9841
# Epoch 27/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0616 - accuracy: 0.9857
# Epoch 28/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0618 - accuracy: 0.9825
# Epoch 29/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9825
# Epoch 30/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 0.9825
# Epoch 31/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0609 - accuracy: 0.9841
# Epoch 32/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0624 - accuracy: 0.9841
# Epoch 33/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0608 - accuracy: 0.9857
# Epoch 34/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0613 - accuracy: 0.9825
# Epoch 35/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0541 - accuracy: 0.9857
# Epoch 36/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0577 - accuracy: 0.9841
# Epoch 37/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0550 - accuracy: 0.9857
# Epoch 38/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0526 - accuracy: 0.9873
# Epoch 39/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0576 - accuracy: 0.9857
# Epoch 40/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0565 - accuracy: 0.9841
# Epoch 41/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0603 - accuracy: 0.9889
# Epoch 42/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0527 - accuracy: 0.9857
# Epoch 43/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0590 - accuracy: 0.9873
# Epoch 44/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0613 - accuracy: 0.9857
# Epoch 45/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0561 - accuracy: 0.9889
# Epoch 46/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0604 - accuracy: 0.9889
# Epoch 47/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9857
# Epoch 48/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0571 - accuracy: 0.9857
# Epoch 49/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0584 - accuracy: 0.9857
# Epoch 50/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9873
# Epoch 51/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0521 - accuracy: 0.9889
# Epoch 52/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0561 - accuracy: 0.9889
# Epoch 53/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0541 - accuracy: 0.9889
# Epoch 54/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0552 - accuracy: 0.9873
# Epoch 55/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0555 - accuracy: 0.9904
# Epoch 56/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0470 - accuracy: 0.9857
# Epoch 57/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0554 - accuracy: 0.9904
# Epoch 58/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0561 - accuracy: 0.9873
# Epoch 59/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9889
# Epoch 60/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0472 - accuracy: 0.9889
# Epoch 61/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9889
# Epoch 62/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0602 - accuracy: 0.9873
# Epoch 63/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9873
# Epoch 64/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0552 - accuracy: 0.9889
# Epoch 65/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0472 - accuracy: 0.9904
# Epoch 66/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0492 - accuracy: 0.9889
# Epoch 67/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0509 - accuracy: 0.9904
# Epoch 68/70
# 126/126 [==============================] - 0s 1ms/step - loss: 0.0496 - accuracy: 0.9889
# Epoch 69/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0540 - accuracy: 0.9889
# Epoch 70/70
# 126/126 [==============================] - 0s 2ms/step - loss: 0.0541 - accuracy: 0.9857

# %%
y_pred = classifier.predict(X_test_smote1)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm11 = confusion_matrix(y_test_smote1, y_pred)


print("[Epoch:70] Our accuracy is {}%".format(((cm11[0][0] + cm11[1][1])/260)*100))

sns.heatmap(cm11,annot=True)
plt.savefig('epoch70.png')
# Out:
# 9/9 [==============================] - 0s 1ms/step
# [Epoch:70] Our accuracy is 95.38461538461539%

# %% [markdown]
# ## AUC for Ensemble Learning Models

# %%
from sklearn.metrics import roc_curve,roc_auc_score

# %%
# df['Insurance'] = df['Insurance'].map({'yes': 1, 'no': 0})
y_test_smote = y_test_smote.map({2: 0, 4: 1})

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, lr.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Logistic Regression')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='red',lw=5)
plt.show()

# %% [markdown]
# ### Support Vector Classifier

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, model4.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Support Vector Classifier')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='red',lw=5)
plt.show()

# %% [markdown]
# ### Random Forest

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, E_model_1.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Random Forest Classifier')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='red',lw=5)
plt.show()

# %% [markdown]
# ### Decision Tree Classifier

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, E_model_2.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Decision Tree Classifier')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='blue',lw=5)
plt.show()

# %% [markdown]
# ### Naive Bayes

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, NB.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Naive Bayes Classifierr')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='green',lw=5)
plt.show()

# %% [markdown]
# ### KNN

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, KNN.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Naive Bayes')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='green',lw=5)
plt.show()

# %% [markdown]
# ### AdaBoost Classifier

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, E_model_3.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC AdaBoost Classifier')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='green',lw=5)
plt.show()

# %% [markdown]
# ### GradientBoosting Classifier

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, E_model_4.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC GradientBoosting Classifier')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='yellow',lw=5)
plt.show()

# %% [markdown]
# ### XgBoost Classifier

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, E_model_5.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC XgBoost Classifier')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='orange',lw=5)
plt.show()

# %% [markdown]
# ### Light GBMClassifier

# %%
plt.figure(figsize=(8, 6))
fpr, tpr, thresholds = roc_curve(y_test_smote, E_model_6.predict_proba(X_test_smote)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC LightGBMClassifier')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='brown',lw=5)
plt.show()

# %% [markdown]
# ARTIFICIAL NEURAL NETWORK

# %%
fpr, tpr, thresholds = roc_curve(y_test_smote1, y_pred)
auc = roc_auc_score(y_test_smote1, y_pred)
print('AUC: %.3f' % auc)

#plotting the auc curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % auc)
plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate or (1 - Specifity)')
plt.ylabel('True Positive Rate or (Sensitivity)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC: 0.954

# %%
from sklearn import metrics
plt.figure(0).clf()

plt.figure(figsize=(6, 6))

y_pred = lr.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="Logistic Regression")



y_pred = model4.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc1 = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="Support Vector Classifier")



y_pred = E_model_1.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc2 = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="Random Forest Classifier, AUC= 0.963")

y_pred = E_model_2.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc3 = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="Decision Tree Classifier, AUC= 0.919")

y_pred = NB.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc4 = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="Naive Bayes, AUC= 0.954")

y_pred = KNN.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc5 = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="KNN, AUC= 0.971")

y_pred = classifier.predict(X_test1)
fpr, tpr, _ = metrics.roc_curve(y_test1, y_pred,)
auc6 = round(metrics.roc_auc_score(y_test1, y_pred), 4)
plt.plot(fpr,tpr,label="Custom ANN")


y_pred = E_model_3.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc7 = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="AdaBoost Classifier")

y_pred = E_model_4.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc8 = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="Gradient Boost")

y_pred = E_model_5.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc9 = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="XGBoost")



y_pred = E_model_6.predict_proba(X_test)[:, 1]
fpr, tpr, _ = metrics.roc_curve(y_test, y_pred, pos_label = 4)
auc10 = round(metrics.roc_auc_score(y_test, y_pred), 4)
plt.plot(fpr,tpr,label="LGBM Classifier")

#add legend
plt.legend(['Logistic Regression AUC: %.4f' % auc,
'Support Vector Classifier AUC: %.4f' % auc1, 
'Random Forest Classifier AUC: %.4f' % auc2, 
'Decision Tree Classifier AUC: %.4f' % auc3,
'Naive Bayes Classifier AUC: %.4f' % auc4,
'KNN Classifier AUC: %.4f' % auc5,
'Custom Classifier AUC: %.4f' % auc6,
'AdaBoost Classifier AUC: %.4f' % auc7,
'GradientBoostingClassifier AUC: %.4f'% auc8,
'XGBoost Classifier AUC: %.4f' % auc9,
'LGBM Classifier AUC: %.4f'% auc10])

plt.title('ROC Curve for all the models')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.grid(True)
plt.show()
plt.savefig("ROCs.png")
# Out:
# 7/7 [==============================] - 0s 1ms/step
