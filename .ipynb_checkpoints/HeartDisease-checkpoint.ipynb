# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %% [markdown]
# ### Reading the CSV file

# %%
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.shape
# Out:
# (1025, 14)

# %%
1025 * 14
# Out:
# 14350

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df['ca'].value_counts()
# Out:
# 0    578
# 1    226
# 2    134
# 3     69
# 4     18
# Name: ca, dtype: int64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# ### Finding correlation among attributes

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df.corr(), annot=True, cmap='terrain')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df)

# %%
df.hist(figsize=(12, 12), layout=(5, 3))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'cp'}>],
#        [<AxesSubplot:title={'center':'trestbps'}>,
#         <AxesSubplot:title={'center':'chol'}>,
#         <AxesSubplot:title={'center':'fbs'}>],
#        [<AxesSubplot:title={'center':'restecg'}>,
#         <AxesSubplot:title={'center':'thalach'}>,
#         <AxesSubplot:title={'center':'exang'}>],
#        [<AxesSubplot:title={'center':'oldpeak'}>,
#         <AxesSubplot:title={'center':'slope'}>,
#         <AxesSubplot:title={'center':'ca'}>],
#        [<AxesSubplot:title={'center':'thal'}>,
#         <AxesSubplot:title={'center':'target'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.plot(kind='box', subplots=True, layout=(5, 3), figsize=(12, 12))
plt.show()

# %%
sns.catplot(data=df, x='sex', y='age', hue='target', palette='Dark2_r')

# %%
sns.barplot(data=df, x='sex', y='chol', hue='target', palette='RdGy')
# barplot gives average value of cholestrol for each sex having heart disease or not
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
df['sex'].value_counts()
# Out:
# 1    713
# 0    312
# Name: sex, dtype: int64

# %%
df['target'].value_counts()
# Out:
# 1    526
# 0    499
# Name: target, dtype: int64

# %%
df['thal'].value_counts()
# Out:
# 2    544
# 3    410
# 1     64
# 0      7
# Name: thal, dtype: int64

# %%
df['oldpeak'].value_counts()
# Out:
# 0.0    329
# 1.2     58
# 1.0     51
# 0.6     47
# 0.8     44
# 1.4     44
# 1.6     37
# 0.2     37
# 1.8     36
# 2.0     32
# 0.4     30
# 0.1     23
# 2.8     22
# 2.6     21
# 3.0     17
# 1.9     16
# 1.5     16
# 3.6     15
# 0.5     15
# 2.2     14
# 4.0     12
# 2.4     11
# 0.3     10
# 3.4     10
# 0.9     10
# 3.2      8
# 2.5      7
# 2.3      7
# 4.2      6
# 1.1      6
# 4.4      4
# 3.8      4
# 5.6      4
# 3.1      4
# 1.3      3
# 2.9      3
# 2.1      3
# 6.2      3
# 0.7      3
# 3.5      3
# Name: oldpeak, dtype: int64

# %%
sns.countplot(x='sex', hue='target', data=df, palette='cividis_r')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex', data=df, palette='cubehelix')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='ca', hue='target', data=df)
# Out:
# <AxesSubplot:xlabel='ca', ylabel='count'>

# %%
sns.countplot(x='thal', data=df, hue='target', palette='ocean_r')
# Out:
# <AxesSubplot:xlabel='thal', ylabel='count'>

# %%
df['cp'].value_counts()
# Out:
# 0    497
# 2    284
# 1    167
# 3     77
# Name: cp, dtype: int64

# %%
sns.countplot(x='cp', data=df, hue='target', palette='tab10_r')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
sns.countplot(x='cp', data=df, hue='sex', palette='bone_r')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
sns.boxplot(x='sex', y='chol', hue='target', data=df, palette="gist_yarg_r"),
# Out:
# (<AxesSubplot:xlabel='sex', ylabel='chol'>,)

# %%
sns.barplot(x='sex', y='cp', hue='target',data=df, palette='cividis')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='cp'>

# %%
sns.barplot(x='sex', y='thal', data=df, hue='target', palette='nipy_spectral')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='thal'>

# %%
sns.barplot(x='target', y='ca', hue='sex', data=df, palette='mako')
# Out:
# <AxesSubplot:xlabel='target', ylabel='ca'>

# %%
sns.barplot(x='sex', y='oldpeak', hue='target', palette='rainbow', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='oldpeak'>

# %% [markdown]
# ### ST depression induced by exercise relative to rest

# %%
df['fbs'].value_counts()
# Out:
# 0    872
# 1    153
# Name: fbs, dtype: int64

# %%
df['chol'].value_counts()
# Out:
# 204    21
# 234    21
# 197    19
# 212    18
# 254    17
#        ..
# 164     3
# 394     3
# 215     3
# 160     3
# 141     3
# Name: chol, Length: 152, dtype: int64

# %% [markdown]
# ## fbs (fasting blood sugar > 120 mg/dl)

# %%
sns.barplot(x='sex', y='chol', hue='target', data=df, palette='YlOrRd_r')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
sns.barplot(x='sex', y='target', hue='fbs', data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='target'>

# %% [markdown]
# ## Plotting Cross tables

# %%
gen = pd.crosstab(df['sex'], df['target'])
gen
# Out:
# target    0    1
# sex
# 0        86  226
# 1       413  300

# %%
gen.plot(kind='bar', stacked=True, color=['blue', 'red'], grid=False)
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
temp=pd.crosstab(index=df['sex'], columns=[df['thal']], margins=True)
temp
# Out:
# thal  0   1    2    3   All
# sex
# 0     3   4  252   53   312
# 1     4  60  292  357   713
# All   7  64  544  410  1025

# %%
temp.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
temp_=pd.crosstab(index=df['target'], columns=[df['thal']], margins=True)
temp_
# Out:
# thal    0   1    2    3   All
# target
# 0       4  43  132  320   499
# 1       3  21  412   90   526
# All     7  64  544  410  1025

# %%
temp_.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='target'>

# %%
chest_pain = pd.crosstab(df['cp'], df['target'])
chest_pain
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
chest_pain.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='cp'>

# %%
chest_pain_sex = pd.crosstab(df['cp'], df['sex'])
chest_pain_sex
# Out:
# sex    0    1
# cp
# 0    133  364
# 1     57  110
# 2    109  175
# 3     13   64

# %%
chest_pain_sex.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='cp'>

# %% [markdown]
# ### Model Building Part

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
Standard_Scaler = StandardScaler()
columns_to_scale = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']
df[columns_to_scale]=Standard_Scaler.fit_transform(df[columns_to_scale])

# %%
df.head()
# Out:
#         age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0 -0.268437    1   0 -0.377636 -0.659332    0        1  0.821321      0
# 1 -0.158157    1   0  0.479107 -0.833861    1        0  0.255968      1
# 2  1.716595    1   0  0.764688 -1.396233    0        1 -1.048692      1
# 3  0.724079    1   0  0.936037 -0.833861    0        1  0.516900      0
# 4  0.834359    0   0  0.364875  0.930822    1        1 -1.874977      0
#
#     oldpeak  slope  ca  thal  target
# 0 -0.060888      2   2     3       0
# 1  1.727137      0   0     3       0
# 2  1.301417      0   0     3       0
# 3 -0.912329      2   1     3       0
# 4  0.705408      1   3     2       0

# %%
X=df.drop(['target'], axis=1)
y=df['target']

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=40)

# %%
print("X_train: ", X_train.size)
print("X_test: ", X_test.size)
print("y_train: ", y_train.size)
print("y_test: ", y_test.size)
# Out:
# X_train:  9321
# X_test:  4004
# y_train:  717
# y_test:  308

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

model=lr.fit(X_train, y_train)
prediction1=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test, prediction1)
cm
# Out:
# array([[115,  38],
#        [ 19, 136]], dtype=int64)

# %%
sns.heatmap(cm, annot=True, cmap='BuPu')
# Out:
# <AxesSubplot:>

# %%
TP, TN, FP, FN = cm[0][0], cm[1][1], cm[0][1], cm[1][0]

# %%
Accuracy=(TP+TN)/(TP+TN+FP+FN)
Accuracy
# Out:
# 0.814935064935065

# %%
from sklearn.metrics import accuracy_score
accuracy_score(prediction1, y_test)
# Out:
# 0.814935064935065

# %%
from sklearn.metrics import classification_report
print(classification_report(prediction1, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.86      0.80       134
#            1       0.88      0.78      0.83       174
#
#     accuracy                           0.81       308
#    macro avg       0.81      0.82      0.81       308
# weighted avg       0.82      0.81      0.82       308

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
model2=dtc.fit(X_train,y_train)
prediction2=model2.predict(X_test)
cm2= confusion_matrix(y_test,prediction2)

# %%
cm2
# Out:
# array([[153,   0],
#        [  3, 152]], dtype=int64)

# %%
sns.heatmap(cm2, annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction2)) #actual value, predicted value
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       153
#            1       1.00      0.98      0.99       155
#
#     accuracy                           0.99       308
#    macro avg       0.99      0.99      0.99       308
# weighted avg       0.99      0.99      0.99       308
